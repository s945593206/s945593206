# %%
import A_DataWash

# %%
import B_Word2Vec
import C_LSTM
import C_BiLSTM
import C_BiLSTM_Attention
import D_Train_Test
# Out:
# .
# 第三遍
# 手册
# 网页链接
# ...
# #
# #
# 深情
# 台前幕后
# .
# #
# .
# 首播
# #
# .
# ...
# ...
# .
# "
# ...
# .
# ...
# 方法
# 吗
# .
# .
# 贴
# .
# ...
# .
# 哈哈哈哈
# 深圳
# ...
# ...
# #
# ...
# ...
# ...
# ...
# ...
# ...
# 网页链接
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# 问答
# #
# 一年
# ...
# )
# ...
# )
# 呀
# .
# .
# .
# .
# ...
# ...
# .
# .
# .
# #
# 什么
# ...
# 秒拍视频
# #
# 了
# 的
# ...
# ...
# ...
# 哦
# .
# ...
# 朴秀荣
# nba
# .
# 感觉
# 了
# )
# "
# ...
# ...
# ...
# ...
# )
# ...
# ...
# ...
# 网页链接
# ...
# 什么
# ...
# #
# .
# ...
# 的
# ...
# ...
# 了
# 时候
# 木子
# 啦
# ...
# ...
# ...
# ...
# ...
# .
# "
# mark
# .
# ...
# .
# 恋爱
# 样子
# .
# 了
# 在意
# .
# "
# .
# ...
# .
# 日记
# 谁
# ...
# 咯
# ...
# 吧
# 东京
# .
# ..
# ......
# 范
# ...
# .
# ...
# ....
# 怎么样
# ...
# ...
# ...
# ...
# "
# 出来
# 存在
# 了
# ...
# #
# 哦
# 嗯
# .
# .
# 工作
# 环境
# 娇
# ...
# #
# 大哥
# .
# 一下
# 网页链接
# 吗
# 啥
# ...
# ...
# 228
# 啊
# 上海
# 你
# 适应
# 干什么
# 了
# 斤
# 的
# 秒拍视频
# #
# ..
# 大结局
# ...
# 咬字清晰
# 灯
# .
# .
# 深圳
# ...
# 顾城
# ...
